# %% [markdown]
# <a href="https://colab.research.google.com/github/thogame/Captura-de-datos-dispositivos/blob/main/CapturadatosApi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Instalación de las librerias o dependencias necesarias
# !pip install beautifulsoup4 requests pandas
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
# Load dependencies
import json # modulo para trabajar con archivos JSON
import requests # libreria para hacer peticiones HTTP
import pandas as pd # libreria para procesar datos, proporciona funciones para analíticas
from bs4 import BeautifulSoup as bs # Extraer información de paginas web

# %%
# Función que convierte una lista de elementos en un dataframe de pandas
def rowsToDataFrame(rows):
    df = pd.DataFrame(rows[1:], columns=rows[0])
    return df

# %%
# Función para extraer los datos de una tabla HTML
def processTableData(tbl):
    rows = []
    for child in tbl.find('tbody').children: # itera los items internos de la tabla [<tr>]
        row = []
        for td in child: # itera los items internos de la tabla [<td>]
            try:
                item = td.text.replace('\n', '') # recupera el texto del elemento [<td>]
                if item:
                    row.append(item) # Agrega cada elemento de la fila
            except:
                continue
        if len(row) > 0:
            rows.append(row) # agrega todos los campos de una fila de la tabla
    # print(rows)
    return rows

# %%
# Función para exxtrar la data de la URL y procesar el contenido HTML
def processDataHTML(data):
    soup = bs(data['sections'][2]['text'], 'html.parser') # Recupera el item del JSON y lo convierte en contenido HTML
    tbl = soup.find_all('table')[0] # Recupera la tabla del contenido HTML
    # print(tbl.prettify())
    tblRows = processTableData(tbl) # Ejecuta la función apra porcesar el contenido de la Tabla
    return tblRows

# %%
# Read website
# r = requests.get('https://www.wikiwand.com/es/Anexo:Tabla_estadística_de_la_Copa_Mundial_de_Fútbol')
r = requests.get('https://www.wikiwand.com/mcs-api/es.wikipedia.org/v1/page/mobile-sections-remaining/%C3%8Dndice_de_desempe%C3%B1o_ambiental')  # Recuperamos el contenido de indice de desempeño ambiental
# print(r)
table = processDataHTML(json.loads(r.content)) # Formate el contenido en formato JSON
df = rowsToDataFrame(table) # ejecuta la funcion para recupera los datos de la tabla como dataframe de Pandas
df
# Out:
#    Puesto Mundial Puesto Continental  \
# 0               1                  1
# 1               2                  2
# 2               3                  3
# 3               4                  4
# 4               5                  5
# 5               6                  6
# 6               7                  7
# 7               8                  8
# 8               9                  9
# 9              10                 10
# 10             11                 11
# 11             12                 12
# 12             13                 13
# 13             14                 14
# 14             15                 15
# 15             16                 16
# 16             17                  1
# 17             18                 17
# 18             19                  1
# 19             20                  2
# 20             21                  2
# 21             22                 18
# 22             23                  3
# 23             24                 19
# 24             25                  1
# 25             26                 20
# 26             27                  2
# 27             28                 21
# 28             29                 22
# 29             30                  3
# 30             31                 23
# 31             32                  4
# 32             33                 24
# 33             34                 25
# 34             35                  4
# 35             36                  5
# 36             37                 26
# 37             38                  5
# 38             39                  1
# 39             40                 27
# 40             41                 28
# 41             42                  6
# 42             43                 29
# 43             44                 30
# 44             45                 31
# 45             46                  7
# 46             47                  8
# 47             48                 32
# 48             49                  6
# 49             50                 33
#
#                                                  País   Región Puntuación 2018
# 0                                         Suiza Suiza   Europa           87.42
# 1                                             Francia   Europa           83.95
# 2                                 Dinamarca Dinamarca   Europa           81.60
# 3                                         Malta Malta   Europa           80.90
# 4                                       Suecia Suecia   Europa           80.51
# 5                             Reino Unido Reino Unido   Europa           79.89
# 6                               Luxemburgo Luxemburgo   Europa           79.12
# 7                                     Austria Austria   Europa           78.97
# 8                                             Irlanda   Europa           78.77
# 9                                 Finlandia Finlandia   Europa           78.64
# 10                                  Islandia Islandia   Europa           78.57
# 11                                      España España   Europa           78.57
# 12                                  Alemania Alemania   Europa           78.37
# 13                                    Noruega Noruega   Europa           77.49
# 14                                    Bélgica Bélgica   Europa           77.38
# 15                                      Italia Italia   Europa           76.96
# 16                        Nueva Zelanda Nueva Zelanda  Oceanía           75.96
# 17                          Países Bajos Países Bajos   Europa           75.46
# 18                                      Israel Israel     Asia           75.01
# 19                                        Japón Japón     Asia           74.69
# 20                                          Australia  Oceanía           74.12
# 21                                      Grecia Grecia   Europa           73.60
# 22                                 República de China     Asia           72.84
# 23                                      Chipre Chipre   Europa           72.60
# 24                                      Canadá Canadá  América           72.18
# 25                                           Portugal   Europa           71.91
# 26                                     Estados Unidos  América           71.19
# 27                              Eslovaquia Eslovaquia   Europa           70.60
# 28                                  Lituania Lituania   Europa           69.33
# 29                              Costa Rica Costa Rica  América           67.85
# 30                                  Bulgaria Bulgaria   Europa           67.85
# 31                                        Catar Catar     Asia           67.80
# 32                    República Checa República Checa   Europa           67.68
# 33                                Eslovenia Eslovenia   Europa           67.57
# 34                Trinidad y Tobago Trinidad y Tobago  América           67.36
# 35  San Vicente y las Granadinas San Vicente y las...  América           66.48
# 36                                    Letonia Letonia   Europa           66.12
# 37                                       Turkmenistán     Asia           66.10
# 38                              Seychelles Seychelles   África           66.02
# 39                                    Albania Albania   Europa           65.46
# 40                                    Croacia Croacia   Europa           65.45
# 41                                  Colombia Colombia  América           65.22
# 42                                    Hungría Hungría   Europa           65.01
# 43                            Bielorrusia Bielorrusia   Europa           64.98
# 44                                    Rumania Rumania   Europa           64.78
# 45          República Dominicana República Dominicana  América           64.71
# 46                                    Uruguay Uruguay  América           64.65
# 47                                    Estonia Estonia   Europa           64.31
# 48                                  Singapur Singapur     Asia           64.23
# 49                                    Polonia Polonia   Europa           64.11

# %%
# Inspeccionamos el tipo de dato de cada variable
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Puesto Mundial      50 non-null     object
#  1   Puesto Continental  50 non-null     object
#  2   País                50 non-null     object
#  3   Región              50 non-null     object
#  4   Puntuación 2018     50 non-null     object
# dtypes: object(5)
# memory usage: 2.1+ KB

# %%
# Guardamos las datos extraidos como archivo CSV
# se puede aplcair otras opciones para guardar (Base de datos)
df.to_csv('statsWorldCup.csv')
